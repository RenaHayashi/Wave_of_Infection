# %%
import matplotlib.pyplot as plt
import math
import random

# %%
# モデルのパラメータ
b0 = 1*10**(-7)
b1 = 2*b0
c = 1.3*10
B = 1
gamma=200
a0=0.01
a1=1.75*a0

# 初期値
x = 1*10**8

# 目安
z2=(c/x - b0) / (b1 - b0)
y2 =( ((1-z2)/z2) *B*(1+gamma*z2**2) - a0)/a1

print(y2, z2)
# Out:
# 2532.7619047619046 0.30000000000000004

# %%
z0 = (c - b0*x)/((b1-b0)*x)
sigma = B*gamma/((b1-b0)*x)
lamda = a0/(B*gamma)
ky = a1/(B*gamma)
f = ((1- z0 )/z0)*(z0*z0+1/gamma)
y0 = f -lamda

print(z0, gamma, sigma, lamda, f, y0)
# Out:
# 0.3 200 20.0 5e-05 0.22166666666666668 0.22161666666666668

# %%
#figa
# x = 1*10**8


y = 2500*ky*random.random()
z = random.random()
t = 0.0

# 時間の設定
dt = 0.01
tEnd = 100
iEnd = int(tEnd/dt)

t_list = [t]
y_list = [y]
z_list = [z]

for i in range(1, iEnd):
    t = dt*i
    y_new = y + dt*(z-z0)*y
    z_new = z + dt*sigma*z*(((1- z )/z)*(z*z+1/gamma) - lamda - y)
    y = y_new
    z = z_new

    t_list.append(t)
    y_list.append(y)
    z_list.append(z)

# %%
# 時間発展のプロット
plt.plot(t_list, y_list)
plt.ylim(0, 0.5)
plt.savefig("fig6a_1.png", format="png", dpi=300)

# %%
# 時間発展のプロット
plt.plot(t_list, z_list, color="black")
plt.ylim(0, 1)
plt.savefig("fig6a_2.png", format="png", dpi=300)

# %%
# # モデルのパラメータ
# b0 = 1*10**(-7)
# b1 = 2*b0
# c = 1.3*10
# B = 1
# gamma=2500
# a0=0.01
# a1=1.75*a0

# # 初期値
# x = 1*10**8

# # 目安
# z2=(c/x - b0) / (b1 - b0)
# y2 =( ((1-z2)/z2) *B*(1+gamma*z2**2) - a0)/a1

# print(y2, z2)

# %%
# z0 = (c - b0*x)/((b1-b0)*x)
# sigma = B*gamma/((b1-b0)*x)
# lamda = a0/(B*gamma)
# ky = a1/(B*gamma)

# print(sigma, lamda,ky)

# %%
# x = 1*10**8

y = 2500*ky*random.random()
z = random.random()
t = 0.0

sigma = 2

# 時間の設定
dt = 0.01
tEnd = 100
iEnd = int(tEnd/dt)

t_list = [t]
y_list = [y]
z_list = [z]

for i in range(1, iEnd):
    t = dt*i
    y_new = y + dt*(z-z0)*y
    z_new = z + dt*sigma*z*(((1- z )/z)*(z*z+1/gamma) - lamda - y)
    y = y_new
    z = z_new

    t_list.append(t)
    y_list.append(y)
    z_list.append(z)

# %%
# 時間発展のプロット
plt.plot(t_list, y_list)
plt.ylim(0, 0.5)
plt.savefig("fig6b_1.png", format="png", dpi=300)

# %%
# 時間発展のプロット
plt.plot(t_list, z_list, color="black")
plt.ylim(0, 1)
plt.savefig("fig6b_2.png", format="png", dpi=300)

# %%
y = 2500*ky*random.random()
z = random.random()
t = 0.0

sigma = 0.2

# 時間の設定
dt = 0.1
tEnd = 500
iEnd = int(tEnd/dt)

t_list = [t]
y_list = [y]
z_list = [z]

for i in range(1, iEnd):
    t = dt*i
    y_new = y + dt*(z-z0)*y
    z_new = z + dt*sigma*z*(((1- z )/z)*(z*z+1/gamma) - lamda - y)
    y = y_new
    z = z_new

    t_list.append(t)
    y_list.append(y)
    z_list.append(z)

# %%
# 時間発展のプロット
plt.plot(t_list, y_list)
# plt.ylim(0, 0.5)
plt.savefig("fig6c_1.png", format="png", dpi=300)

# %%
# 時間発展のプロット
plt.plot(t_list, z_list, color="black")
plt.ylim(0, 1)
plt.savefig("fig6c_2.png", format="png", dpi=300)

# %%
y = 2500*ky*random.random()
z = random.random()
t = 0.0

sigma = 200

# 時間の設定
dt = 0.1
tEnd = 100
iEnd = int(tEnd/dt)

t_list = [t]
y_list = [y]
z_list = [z]

for i in range(1, iEnd):
    t = dt*i
    y_new = y + dt*(z-z0)*y
    z_new = z + dt*sigma*z*(((1- z )/z)*(z*z+1/gamma) - lamda - y)
    y = y_new
    z = z_new

    t_list.append(t)
    y_list.append(y)
    z_list.append(z)

# %%
# 時間発展のプロット
plt.plot(t_list, y_list)
# plt.ylim(0, 0.5)
plt.savefig("fig6d_1.png", format="png", dpi=300)

# %%
# 時間発展のプロット
plt.plot(t_list, z_list, color="black")
plt.ylim(0, 1)
plt.savefig("fig6d_2.png", format="png", dpi=300)
